# %%
import warnings
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import features as f
warnings.filterwarnings('ignore')
pd.set_option("max_columns", 100)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
get_ipython().run_line_magic('load_ext', 'autoreload')
get_ipython().run_line_magic('autoreload', '2')
get_ipython().run_line_magic('matplotlib', 'inline')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv('creditcard.csv')

# %%
X_train, X_test, y_train, y_test = f.train_test(data.iloc[:, :-1], data[['Class']])

# %%
X_train, y_train = f.smote_under(X_train, y_train)

# %%
X_train, X_dev, y_train, y_dev = f.train_test(X_train.iloc[:, :-1], y_train[['Class']])

# %%
columns = list(X_dev.columns)
for col in columns:
    sns.boxplot(x=y_train['Class'], y=X_train[col])
    plt.title(col)
    plt.show()

# %%
train = pd.concat([X_train, y_train], axis=1)
dev = pd.concat([X_dev, y_dev], axis=1)
test = pd.concat([X_test, y_test], axis=1)
train, dev, test = f.cap_outliers(train, dev, test)
X_train, y_train = train.iloc[:, :-1], train[['Class']]
X_dev, y_dev = dev.iloc[:, :-1], dev[['Class']]
X_test, y_test = test.iloc[:, :-1], test[['Class']]

# %%
columns = list(X_dev.columns)
for col in columns:
    sns.boxplot(x=y_train['Class'], y=X_train[col])
    plt.title(col)
    plt.show()

# %%
columns = list(train.columns)
for col in columns:
    sns.pairplot(data = train, x_vars = [col], y_vars = columns, hue="Class")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-018144240be2> in <module>
#       1 columns = list(train.columns)
#       2 for col in columns:
# ----> 3     sns.pairplot(data = train, x_vars = [col], y_vars = columns, hue="Class")
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2119     if kind == "scatter":
#    2120         from .relational import scatterplot  # Avoid circular import
# -> 2121         plotter(scatterplot, **plot_kws)
#    2122     elif kind == "reg":
#    2123         from .regression import regplot  # Avoid circular import
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map(self, func, **kwargs)
# ...

# %%
columns = list(X_train.columns)
for i in list(range(len(columns))):
    if 1<=(i+1)<5:
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[(i+1):5], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[5:10], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[10:15], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[15:20], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[20:25], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[25:], hue = "Class")
        plt.show()
    elif 5<=(i+1)<10:
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[(i+1):10], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[10:15], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[15:20], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[20:25], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[25:], hue = "Class")
        plt.show()
    elif 10<=(i+1)<15:
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[(i+1):15], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[15:20], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[20:25], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[25:], hue = "Class")
        plt.show()
    elif 15<=(i+1)<20:
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[(i+1):20], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[20:25], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[25:], hue = "Class")
        plt.show()
    elif 20<=(i+1)<25:
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[(i+1):25], hue = "Class")
        plt.show()
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[25:], hue = "Class")
        plt.show()
    elif 25<=(i+1)<28:
        sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[(i+1):], hue = "Class")
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-4ea8ae991b9c> in <module>
#      18         plt.show()
#      19         sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[10:15], hue = "Class")
# ---> 20         plt.show()
#      21         sns.pairplot(data=train, y_vars = [columns[i]], x_vars = columns[15:20], hue = "Class")
#      22         plt.show()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     261     """
#     262     global _show
# --> 263     return _show(*args, **kw)
#     264
#     265
#
# ~\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...
